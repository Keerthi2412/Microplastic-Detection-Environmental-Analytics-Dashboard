# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dim_locations.csv")
df.head()
# Out:
#   Location_ID          Location_Name Water_Body_Type  Latitude  Longitude  \
# 0     LOC-101     Hudson River North           River   40.7128   -74.0060
# 1     LOC-102  Lake Michigan Central            Lake   41.8781   -87.6298
# 2     LOC-103       Bay Area Estuary         Estuary   37.7749  -122.4194
# 3     LOC-104       City WWTP Outlet   WWTP Effluent   40.7306   -73.9352
# 4     LOC-105    Puget Sound Coastal         Coastal   47.6062  -122.3321
#
#             City State Nearby_Industry_Type
# 0       New York    NY    Textile & Apparel
# 1        Chicago    IL        Manufacturing
# 2  San Francisco    CA    Tech & Commercial
# 3       New York    NY     Municipal Sewage
# 4        Seattle    WA  Maritime & Shipping

# %%
df.tail()
# Out:
#   Location_ID         Location_Name Water_Body_Type  Latitude  Longitude  \
# 5     LOC-106     Mississippi Delta           River   29.9511   -90.0715
# 6     LOC-107      Everglades Canal         Wetland   25.7617   -80.1918
# 7     LOC-108  Delaware River Basin           River   39.9526   -75.1652
# 8     LOC-109        Lake Erie West            Lake   41.5055   -81.6944
# 9     LOC-110     Chesapeake Inflow         Estuary   38.9784   -76.4922
#
#            City State Nearby_Industry_Type
# 5   New Orleans    LA   Agriculture Runoff
# 6         Miami    FL   Agriculture Runoff
# 7  Philadelphia    PA  Chemical Processing
# 8     Cleveland    OH     Heavy Industrial
# 9     Annapolis    MD         Urban Runoff

# %%
df.columns
# Out:
# Index(['Location_ID', 'Location_Name', 'Water_Body_Type', 'Latitude',
#        'Longitude', 'City', 'State', 'Nearby_Industry_Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 8)

# %%
df.dtypes
# Out:
# Location_ID              object
# Location_Name            object
# Water_Body_Type          object
# Latitude                float64
# Longitude               float64
# City                     object
# State                    object
# Nearby_Industry_Type     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Location_ID             0
# Location_Name           0
# Water_Body_Type         0
# Latitude                0
# Longitude               0
# City                    0
# State                   0
# Nearby_Industry_Type    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Location_ID             0
# Location_Name           0
# Water_Body_Type         0
# Latitude                0
# Longitude               0
# City                    0
# State                   0
# Nearby_Industry_Type    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
text_columns = df.select_dtypes(include='object').columns

for col in text_columns:
    df[col] = df[col].str.strip()

# %%
for col in text_columns:
    df[col] = df[col].str.title()

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Location_ID             0
# Location_Name           0
# Water_Body_Type         0
# Latitude                0
# Longitude               0
# City                    0
# State                   0
# Nearby_Industry_Type    0
# dtype: int64

# %%
df.to_csv("dim_locations_cleaned.csv", index=False)
